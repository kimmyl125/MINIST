# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
software_df=pd.read_csv('/content/drive/My Drive/Software.csv')

# %%
import pandas as pd
studies_df=pd.read_csv('/content/drive/My Drive/Studies.csv')

# %%
import pandas as pd
programmer_df=pd.read_csv('/content/drive/My Drive/Programmer.csv')

# %%
import pandas as pd
customers_df=pd.read_csv('/content/drive/My Drive/Customers.csv')

# %%
display(software_df)
# Out:
#        PNAME            TITLE DEVELOPIN     SCOST  DCOST  SOLD
# 0       MARY           README       CPP    300.00   1200    84
# 1      ANAND       PARACHUTES     BASIC    399.95   6000    43
# 2      ANAND    VIDEO TITLING    PASCAL   7500.00  16000     9
# 3    JULIANA        INVENTORY     COBOL   3000.00   3500     0
# 4     KAMALA     PAYROLL PKG.     DBASE   9000.00  20000     7
# 5       MARY  FINANCIAL ACCT.    ORACLE  18000.00  85000     4
# 6       MARY   CODE GENERATOR         C   4500.00  20000    23
# 7   PATTRICK           README       CPP    300.00   1200    84
# 8      QADIR       BOMBS AWAY  ASSEMBLY    750.00   3000    11
# 9      QADIR         VACCINES         C   1900.00   3100    21
# 10    RAMESH      HOTEL MGMT.     DBASE  13000.00  35000     4
# 11    RAMESH         DEAD LEE    PASCAL    599.95   4500    73
# 12   REMITHA     PC UTILITIES         C    725.00   5000    51
# 13   REMITHA    TSR HELP PKG.  ASSEMBLY   2500.00   6000     7
# ...

# %%
import matplotlib.pyplot as plt
import plotly.express as px
fig=px.histogram(software_df,x='DEVELOPIN',title='count of developin',color='DEVELOPIN')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pie_fig=px.pie(software_df,names='DEVELOPIN',title='count of developin')
pie_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(software_df['DEVELOPIN'])
plt.xlabel('DEVELOPIN')
plt.ylabel('Count')
plt.title('Count of DEVELOPIN')
plt.show()

# %%
fig_line=px.line(software_df,x='DEVELOPIN',title='count of developin',color='DEVELOPIN')
fig_line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig_line=px.scatter(software_df,x='DEVELOPIN',title='count of developin',color='DEVELOPIN')
fig_line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ca6b09ef27bc> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 Diwalidata_df=pd.read_csv('/content/drive/My Drive/Diwalidata.csv')
#       3 display(Diwalidata_df.head())
#
# ...
